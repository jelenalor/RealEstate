# %%
import numpy as np 
import pandas as pd
import os
import psycopg2

import importlib
from Secrets import secrets
# importlib.reload(secrets)

import matplotlib.pyplot as plt

# %% [markdown]
# ### Pull Data from a custom made AWS Database of public data
# Define an engine to query AWS DB and set up the execution

# %%
# Define Engine
engine = psycopg2.connect(
    database="postgres",
    user=secrets.user(),
    password=secrets.password(),
    host=secrets.host(),
    port='5432'
)

cur = engine.cursor()

# %%
cur.execute("""

SELECT 
    lsoa, EXTRACT(YEAR FROM date), cat_group, sum(value)

from crime

group by 1, 2, 3;




""")
rows = cur.fetchall()
result = pd.DataFrame(rows, columns = [desc[0] for desc in cur.description])
result
# Out:
#              lsoa  date_part        cat_group   sum
# 0       E01000006     2008.0  Criminal Damage   7.0
# 1       E01000006     2008.0            Drugs   8.0
# 2       E01000006     2008.0            Other   0.0
# 3       E01000006     2008.0          Robbery  18.0
# 4       E01000006     2008.0            Theft  37.0
# ...           ...        ...              ...   ...
# 376475  E01033746     2020.0            Drugs   5.0
# 376476  E01033746     2020.0            Other  20.0
# 376477  E01033746     2020.0          Robbery  12.0
# 376478  E01033746     2020.0            Theft   9.0
# 376479  E01033746     2020.0         Violence  12.0
#
# [376480 rows x 4 columns]

# %%
fig, ax = plt.subplots(figsize = (10, 4))

df = result.groupby("cat_group")["sum"].sum().reset_index()
width = 0.35
labels = df["cat_group"].to_list()
x = np.arange(len(labels))
y = df["sum"].to_list()

ax.bar(x, y, width)

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('# of crime cases')
ax.set_title('Num of crime cases by category')
ax.set_xticks(x)
ax.set_xticklabels(labels)

plt.show()

# %%
cur.execute("""

select * from geo limit 5;


""")
rows = cur.fetchall()
result = pd.DataFrame(rows, columns = [desc[0] for desc in cur.description])
result

# %%
import geopandas as gpd

sql = """
select * from geo limit 5;
"""

gpd.read_postgis(sql, engine, geom_col='geometry')
# Out:
#         lsoa                  lsoa_name         rg               rg_name  \
# 0  E01000001        City of London 001A  E12000007        City of London
# 1  E01000002        City of London 001B  E12000007        City of London
# 2  E01000003        City of London 001C  E12000007        City of London
# 3  E01000005        City of London 001E  E12000007        City of London
# 4  E01000006  Barking and Dagenham 016A  E12000007  Barking and Dagenham
#
#    no_of_res  pop_den                                           geometry
# 0     1465.0    112.9  POLYGON ((532105.092 182011.230, 532162.491 18...
# 1     1436.0     62.9  POLYGON ((532746.813 181786.891, 532671.688 18...
# 2     1346.0    227.7  POLYGON ((532135.145 182198.119, 532158.250 18...
# 3      985.0     52.0  POLYGON ((533807.946 180767.770, 533649.063 18...
# 4     1703.0    116.2  POLYGON ((545122.049 184314.931, 545271.917 18...
